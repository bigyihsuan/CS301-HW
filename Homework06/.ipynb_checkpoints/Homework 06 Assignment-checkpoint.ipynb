# %% [markdown]
# ## Author: Yi-Hsuan Hsu
# ## Date: 4/3/20
# ## CS301-006, Professor Watson
# ## HW06 Solution
#
# The purpose of this assignment is to help students practice using Python to prepare their data sets for machine learning.
#
# link to the git repo: https://github.com/bigyihsuan/CS301-HW/commit/4725332a6be87bbcbd0a755eb01b20ec9b586b00

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Question 1 - Read in the data set and print the % empty values for each column. Are there any columns with missing values?

# %%
data_dir = 'groundhog.csv'

# %%
df = pd.read_csv(data_dir)
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#      Year Punxsutawney Phil  February Average Temperature  \
# 0    1886         No Record                           NaN
# 1    1887       Full Shadow                           NaN
# 2    1888       Full Shadow                           NaN
# 3    1889         No Record                           NaN
# 4    1890         No Shadow                           NaN
# ..    ...               ...                           ...
# 126  2012       Full Shadow                         37.51
# 127  2013         No Shadow                         34.77
# 128  2014       Full Shadow                         32.13
# 129  2015       Full Shadow                         32.99
# 130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      47.7
# 127                                      33.9
# 128                                      30.3
# 129                                      31.6
# 130                                      43.4
#
# [131 rows x 10 columns]

# %%
for col in df.columns:
    total = df.shape[0]
    empty = df.loc[df[col].isna()]
    numE = empty.shape[0]
    print("{}: {}%".format(col, (1-numE/total)*100))
# Out:
# Year: 100.0%
# Punxsutawney Phil: 100.0%
# February Average Temperature: 93.12977099236642%
# February Average Temperature (Northeast): 93.12977099236642%
# February Average Temperature (Midwest): 93.12977099236642%
# February Average Temperature (Pennsylvania): 93.12977099236642%
# March Average Temperature: 93.12977099236642%
# March Average Temperature (Northeast): 93.12977099236642%
# March Average Temperature (Midwest): 93.12977099236642%
# March Average Temperature (Pennsylvania): 93.12977099236642%

# %% [markdown]
# All columns except for "Year" and "Punx..." have missing values.

# %% [markdown]
# #### Question 2 - Create a new dataframe which is a copy of the orginal one. In this copy, replace the missing values in the data set using one of the discussed methods in class.

# %%
new_df = df.copy()
# replace N/A with column average
for col in new_df.columns[2:]:
    new_df[col].fillna(new_df[col].mean(), inplace=True)
new_df
# Out:
#      Year Punxsutawney Phil  February Average Temperature  \
# 0    1886         No Record                     33.802705
# 1    1887       Full Shadow                     33.802705
# 2    1888       Full Shadow                     33.802705
# 3    1889         No Record                     33.802705
# 4    1890         No Shadow                     33.802705
# ..    ...               ...                           ...
# 126  2012       Full Shadow                     37.510000
# 127  2013         No Shadow                     34.770000
# 128  2014       Full Shadow                     32.130000
# 129  2015       Full Shadow                     32.990000
# 130  2016         No Shadow                     39.470000
#
#      February Average Temperature (Northeast)  \
# 0                                   22.693443
# 1                                   22.693443
# 2                                   22.693443
# 3                                   22.693443
# 4                                   22.693443
# ..                                        ...
# 126                                 30.600000
# 127                                 25.300000
# 128                                 21.000000
# 129                                 12.100000
# 130                                 28.100000
#
#      February Average Temperature (Midwest)  \
# 0                                 32.694262
# 1                                 32.694262
# 2                                 32.694262
# 3                                 32.694262
# 4                                 32.694262
# ..                                      ...
# 126                               38.600000
# 127                               33.400000
# 128                               27.100000
# 129                               23.400000
# 130                               36.900000
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                      26.522951                  41.699016
# 1                                      26.522951                  41.699016
# 2                                      26.522951                  41.699016
# 3                                      26.522951                  41.699016
# 4                                      26.522951                  41.699016
# ..                                           ...                        ...
# 126                                    34.300000                  50.410000
# 127                                    27.400000                  40.910000
# 128                                    22.800000                  40.510000
# 129                                    16.100000                  45.390000
# 130                                    30.800000                  47.500000
#
#      March Average Temperature (Northeast)  \
# 0                                32.368033
# 1                                32.368033
# 2                                32.368033
# 3                                32.368033
# 4                                32.368033
# ..                                     ...
# 126                              43.400000
# 127                              32.700000
# 128                              26.000000
# 129                              27.800000
# 130                              38.800000
#
#      March Average Temperature (Midwest)  \
# 0                              42.568852
# 1                              42.568852
# 2                              42.568852
# 3                              42.568852
# 4                              42.568852
# ..                                   ...
# 126                            56.300000
# 127                            37.300000
# 128                            38.000000
# 129                            41.600000
# 130                            49.500000
#
#      March Average Temperature (Pennsylvania)
# 0                                   35.908197
# 1                                   35.908197
# 2                                   35.908197
# 3                                   35.908197
# 4                                   35.908197
# ..                                        ...
# 126                                 47.700000
# 127                                 33.900000
# 128                                 30.300000
# 129                                 31.600000
# 130                                 43.400000
#
# [131 rows x 10 columns]

# %% [markdown]
# #### Question 3 - Is your proposed method from Question 2 appropriate in this case? Why or why not?

# %% [markdown]
# It's appropiate in this case because all the column values are average temperatures for a given month of a given year. In addition, the NAs are where there are missing temperature values.

# %% [markdown]
# #### Question 4 - Using the original dataframe (unchanged from Questoins 2, 3), create a mapping for the "Punxsutawney Phil" column which changes the categories into numerical quantities. For example: 'No Record' can be 0, 'No Shadow' can be 1, 'Partial Shadow' can be 2, and 'Full Shadow' can be 3. You should create the mapping *and* apply it to the data set by adding a new column called "Shadow".

# %%
shadows = df["Punxsutawney Phil"].copy();
shadows.replace(["No Record", "No Shadow", "Partial Shadow", "Full Shadow"], [0, 1, 2, 3], inplace=True)
shadows
# Out:
# 0      0
# 1      3
# 2      3
# 3      0
# 4      1
#       ..
# 126    3
# 127    1
# 128    3
# 129    3
# 130    1
# Name: Punxsutawney Phil, Length: 131, dtype: int64

# %%
df["Shadow"] = shadows
df
# Out:
#      Year Punxsutawney Phil  February Average Temperature  \
# 0    1886         No Record                           NaN
# 1    1887       Full Shadow                           NaN
# 2    1888       Full Shadow                           NaN
# 3    1889         No Record                           NaN
# 4    1890         No Shadow                           NaN
# ..    ...               ...                           ...
# 126  2012       Full Shadow                         37.51
# 127  2013         No Shadow                         34.77
# 128  2014       Full Shadow                         32.13
# 129  2015       Full Shadow                         32.99
# 130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 0                                         NaN       0
# 1                                         NaN       3
# 2                                         NaN       3
# 3                                         NaN       0
# 4                                         NaN       1
# ..                                        ...     ...
# 126                                      47.7       3
# 127                                      33.9       1
# 128                                      30.3       3
# 129                                      31.6       3
# 130                                      43.4       1
#
# [131 rows x 11 columns]

# %% [markdown]
# #### Question 5 - For all rows which have no record, remove the rows which have empty values in all of the quantitative columns. (Only 6 should be removed.)

# %%
copy = df.copy()
copy.drop(copy.loc[copy["Shadow"]==0].loc[copy["February Average Temperature"].isna()].index, inplace=True)
copy
# Out:
#      Year Punxsutawney Phil  February Average Temperature  \
# 1    1887       Full Shadow                           NaN
# 2    1888       Full Shadow                           NaN
# 4    1890         No Shadow                           NaN
# 9    1895         No Record                         26.60
# 10   1896         No Record                         35.04
# ..    ...               ...                           ...
# 126  2012       Full Shadow                         37.51
# 127  2013         No Shadow                         34.77
# 128  2014       Full Shadow                         32.13
# 129  2015       Full Shadow                         32.99
# 130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 1                                         NaN
# 2                                         NaN
# 4                                         NaN
# 9                                        15.6
# 10                                       22.2
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 1                                       NaN
# 2                                       NaN
# 4                                       NaN
# 9                                      21.9
# 10                                     33.5
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 4                                            NaN                        NaN
# 9                                           17.0                      39.97
# 10                                          26.6                      38.03
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 1                                      NaN
# 2                                      NaN
# 4                                      NaN
# 9                                     27.6
# 10                                    25.3
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 1                                    NaN
# 2                                    NaN
# 4                                    NaN
# 9                                   40.2
# 10                                  36.9
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 1                                         NaN       3
# 2                                         NaN       3
# 4                                         NaN       1
# 9                                        31.3       0
# 10                                       27.8       0
# ..                                        ...     ...
# 126                                      47.7       3
# 127                                      33.9       1
# 128                                      30.3       3
# 129                                      31.6       3
# 130                                      43.4       1
#
# [125 rows x 11 columns]

# %% [markdown]
# #### Question 6 - For the remaining rows which have no record (but the other columns *are* populated), determine an appropriate method for inputting the value for this column. Explain your reasoning, and show your work below (using pandas).

# %% [markdown]
# The mode of the `"Shadow"/"Pun..."` column should be filled in, since they would be the most common value in the column.

# %%
copy["Punxsutawney Phil"].replace(["No Record"], [copy["Punxsutawney Phil"].mode()], inplace=True)
copy["Shadow"].replace([0], [copy["Shadow"].mode()], inplace=True)
copy
# Out:
#      Year Punxsutawney Phil  February Average Temperature  \
# 1    1887       Full Shadow                           NaN
# 2    1888       Full Shadow                           NaN
# 4    1890         No Shadow                           NaN
# 9    1895       Full Shadow                         26.60
# 10   1896       Full Shadow                         35.04
# ..    ...               ...                           ...
# 126  2012       Full Shadow                         37.51
# 127  2013         No Shadow                         34.77
# 128  2014       Full Shadow                         32.13
# 129  2015       Full Shadow                         32.99
# 130  2016         No Shadow                         39.47
#
#      February Average Temperature (Northeast)  \
# 1                                         NaN
# 2                                         NaN
# 4                                         NaN
# 9                                        15.6
# 10                                       22.2
# ..                                        ...
# 126                                      30.6
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
#
#      February Average Temperature (Midwest)  \
# 1                                       NaN
# 2                                       NaN
# 4                                       NaN
# 9                                      21.9
# 10                                     33.5
# ..                                      ...
# 126                                    38.6
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
#
#      February Average Temperature (Pennsylvania)  March Average Temperature  \
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 4                                            NaN                        NaN
# 9                                           17.0                      39.97
# 10                                          26.6                      38.03
# ..                                           ...                        ...
# 126                                         34.3                      50.41
# 127                                         27.4                      40.91
# 128                                         22.8                      40.51
# 129                                         16.1                      45.39
# 130                                         30.8                      47.50
#
#      March Average Temperature (Northeast)  \
# 1                                      NaN
# 2                                      NaN
# 4                                      NaN
# 9                                     27.6
# 10                                    25.3
# ..                                     ...
# 126                                   43.4
# 127                                   32.7
# 128                                   26.0
# 129                                   27.8
# 130                                   38.8
#
#      March Average Temperature (Midwest)  \
# 1                                    NaN
# 2                                    NaN
# 4                                    NaN
# 9                                   40.2
# 10                                  36.9
# ..                                   ...
# 126                                 56.3
# 127                                 37.3
# 128                                 38.0
# 129                                 41.6
# 130                                 49.5
#
#      March Average Temperature (Pennsylvania)  Shadow
# 1                                         NaN       3
# 2                                         NaN       3
# 4                                         NaN       1
# 9                                        31.3       3
# 10                                       27.8       3
# ..                                        ...     ...
# 126                                      47.7       3
# 127                                      33.9       1
# 128                                      30.3       3
# 129                                      31.6       3
# 130                                      43.4       1
#
# [125 rows x 11 columns]

# %% [markdown]
# #### Question 7 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the independent variables X? Why?
#
# #### Use pandas to assign a variable X to be all of the rows of the data set with the column(s) that represent the independent variables.

# %% [markdown]
# `X` should be the `"Year"` column because that is the value that the model will get after training to generate a shadow.

# %%
X = copy["Year"]
X
# Out:
# 1      1887
# 2      1888
# 4      1890
# 9      1895
# 10     1896
#        ...
# 126    2012
# 127    2013
# 128    2014
# 129    2015
# 130    2016
# Name: Year, Length: 125, dtype: int64

# %% [markdown]
# #### Question 8 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the dependent variables Y? Why?
#
# #### Use pandas to assign a variable Y to be all of the rows of the data set with the column(s) that represent the dependent variables.

# %% [markdown]
# `Y` should be either the `"Pun..."` or `"Shadow"` columns. We want the model to output a shadow for a given year, so the shadow is the dependent value. It would be more useful to use the `"Shadow"` column since it is a numeric value.

# %%
Y = copy["Shadow"]
Y
# Out:
# 1      3
# 2      3
# 4      1
# 9      3
# 10     3
#       ..
# 126    3
# 127    1
# 128    3
# 129    3
# 130    1
# Name: Shadow, Length: 125, dtype: int64

# %% [markdown]
# #### Question 9 - Using the train_test_split function from the sklearn module, use a 70/30 split validation to split the data set into train and test. If you follow the example at the following link: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# Note: It's common practice to use the following variable names for unpacking the result:
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=(YOUR VALUE))
#
# sklearn will create a proper split where the following statements hold true:
# X_train is your train set independent variables
# Y_train is your train set dependent variables
# X_test is your test set independent variables
# Y_test is your test set dependent variables

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %% [markdown]
# #### Question 10 - Should the number of rows in X_train == number of rows in Y_train? Also, should the number of rows in X_test == Y_test? Why or why not? Validate your answer with code below:

# %% [markdown]
# For the first, they should because the model needs to build its predictions based on both values that it gets. For the second, it also should be the same so that the model can test its predictions against the actual values.

# %%
X_train, Y_train
# Out:
# (29     1915
#  121    2007
#  27     1913
#  104    1990
#  19     1905
#         ...
#  111    1997
#  83     1969
#  23     1909
#  106    1992
#  123    2009
#  Name: Year, Length: 87, dtype: int64, 29     3
#  121    1
#  27     3
#  104    1
#  19     3
#        ..
#  111    1
#  83     3
#  23     3
#  106    3
#  123    3
#  Name: Shadow, Length: 87, dtype: int64)

# %%
X_test, Y_test
# Out:
# (64     1950
#  101    1987
#  17     1903
#  42     1928
#  103    1989
#  128    2014
#  96     1982
#  33     1919
#  120    2006
#  113    1999
#  95     1981
#  28     1914
#  37     1923
#  41     1927
#  1      1887
#  60     1946
#  74     1960
#  118    2004
#  9      1895
#  66     1952
#  57     1943
#  14     1900
#  110    1996
#  100    1986
#  112    1998
#  124    2010
#  38     1924
#  50     1936
#  25     1911
#  62     1948
#  105    1991
#  78     1964
#  49     1935
#  117    2003
#  18     1904
#  126    2012
#  16     1902
#  119    2005
#  Name: Year, dtype: int64, 64     1
#  101    3
#  17     3
#  42     3
#  103    3
#  128    3
#  96     3
#  33     3
#  120    3
#  113    1
#  95     3
#  28     3
#  37     3
#  41     3
#  1      3
#  60     3
#  74     3
#  118    3
#  9      3
#  66     3
#  57     3
#  14     3
#  110    3
#  100    1
#  112    3
#  124    3
#  38     3
#  50     3
#  25     3
#  62     3
#  105    3
#  78     3
#  49     3
#  117    3
#  18     3
#  126    3
#  16     3
#  119    3
#  Name: Shadow, dtype: int64)
